# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from collections import Counter

# %%
# Loading data
file_path = "delhi_weather_cleaned.csv"
df = pd.read_csv(file_path, index_col=0)
df
# Out:
#           datetime_utc conds  dewptm  fog  hail   hum  pressurem  rain  snow  \
# 0       19961101-11:00  Haze     9.0    0     0  27.0     1010.0     0     0
# 4       19961101-16:00  Haze    11.0    0     0  47.0     1011.0     0     0
# 6       19961101-18:00  Haze    13.0    0     0  60.0     1010.0     0     0
# 14      19961102-02:00  Haze    10.0    0     0  52.0     1011.0     0     0
# 15      19961102-03:00  Haze    10.0    0     0  46.0     1012.0     0     0
# ...                ...   ...     ...  ...   ...   ...        ...   ...   ...
# 100985  20170424-06:00  Haze    17.0    0     0  25.0     1005.0     0     0
# 100986  20170424-09:00  Haze    14.0    0     0  16.0     1003.0     0     0
# 100987  20170424-12:00  Haze    12.0    0     0  14.0     1002.0     0     0
# 100988  20170424-15:00  Haze    15.0    0     0  27.0     1004.0     0     0
# 100989  20170424-18:00  Haze    15.0    0     0  30.0     1005.0     0     0
#
#         tempm  thunder  tornado  vism  wdird  wdire  wspdm
# 0        30.0        0        0   5.0  280.0   West    7.4
# 4        23.0        0        0   1.2    0.0  North    0.0
# 6        21.0        0        0   0.8    0.0  North    0.0
# 14       20.0        0        0   2.0  200.0    SSW    9.3
# 15       22.0        0        0   3.5  240.0    WSW    9.3
# ...       ...      ...      ...   ...    ...    ...    ...
# 100985   34.0        0        0   4.0  320.0     NW   11.1
# 100986   38.0        0        0   4.0  320.0     NW   22.2
# 100987   36.0        0        0   4.0  270.0   West   18.5
# 100988   32.0        0        0   2.0  320.0     NW    3.7
# 100989   30.0        0        0   2.0  320.0     NW    3.7
#
# [80657 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['datetime_utc', 'conds', 'dewptm', 'fog', 'hail', 'hum', 'pressurem',
#        'rain', 'snow', 'tempm', 'thunder', 'tornado', 'vism', 'wdird', 'wdire',
#        'wspdm'],
#       dtype='object')

# %%
df.dtypes
# Out:
# datetime_utc     object
# conds            object
# dewptm          float64
# fog               int64
# hail              int64
# hum             float64
# pressurem       float64
# rain              int64
# snow              int64
# tempm           float64
# thunder           int64
# tornado           int64
# vism            float64
# wdird           float64
# wdire            object
# wspdm           float64
# dtype: object

# %%
print(df['wdire'].value_counts())
print("No of unique directions:",len(df["wdire"].unique()))
# Out:
# North       15701
# West        11450
# WNW          7232
# East         7038
# NW           6946
# WSW          5202
# ESE          5195
# ENE          3581
# SE           3427
# SW           3072
# NNW          2625
# NE           2410
# SSE          1981
# SSW          1656
# NNE          1635
# South        1501
# Variable        5
# Name: wdire, dtype: int64
# No of unique directions: 17

# %%
# Dimension reduction
df["wdire"]=df["wdire"].replace(["WNW", "WSW", "ESE", "ENE", "NNW", "SSE", "NNE" ,"SSW", "Variable"], ["West", "West", "East", "East", "North", "South", "North", "South", "North"])

# %%
print(df['wdire'].value_counts())
# Out:
# West     23884
# North    19966
# East     15814
# NW        6946
# South     5138
# SE        3427
# SW        3072
# NE        2410
# Name: wdire, dtype: int64

# %%
deg=45
df["wdire"]=df["wdire"].replace(["North","NE", "East","SE", "South","SW", "West", "NW"], [0, deg, 2*deg, 3*deg, 4*deg, 5*deg, 6*deg, 7*deg])

# %%
df["wdire"].value_counts()
# Out:
# 270    23884
# 0      19966
# 90     15814
# 315     6946
# 180     5138
# 135     3427
# 225     3072
# 45      2410
# Name: wdire, dtype: int64

# %% [markdown]
# Reduced the amount of variables in the 'wdire' column vs creating  new features using pd.get_dummies.

# %%
# Dropping wdird because it is now a duplicate.
df = df.drop(['datetime_utc', 'wdird'], axis =1)
df.head()
# Out:
#    conds  dewptm  fog  hail   hum  pressurem  rain  snow  tempm  thunder  \
# 0   Haze     9.0    0     0  27.0     1010.0     0     0   30.0        0
# 4   Haze    11.0    0     0  47.0     1011.0     0     0   23.0        0
# 6   Haze    13.0    0     0  60.0     1010.0     0     0   21.0        0
# 14  Haze    10.0    0     0  52.0     1011.0     0     0   20.0        0
# 15  Haze    10.0    0     0  46.0     1012.0     0     0   22.0        0
#
#     tornado  vism  wdire  wspdm
# 0         0   5.0    270    7.4
# 4         0   1.2      0    0.0
# 6         0   0.8      0    0.0
# 14        0   2.0    180    9.3
# 15        0   3.5    270    9.3

# %%
df.describe()
# Out:
#              dewptm           fog          hail           hum     pressurem  \
# count  80657.000000  80657.000000  80657.000000  80657.000000  8.065700e+04
# mean      15.676445      0.050907      0.000136     55.171926  2.199730e+03
# std        7.150146      0.219809      0.011677     23.447379  3.558458e+05
# min      -24.000000      0.000000      0.000000      4.000000 -9.999000e+03
# 25%       10.000000      0.000000      0.000000     36.000000  1.001000e+03
# 50%       15.000000      0.000000      0.000000     55.000000  1.008000e+03
# 75%       22.000000      0.000000      0.000000     74.000000  1.014000e+03
# max       35.000000      1.000000      1.000000    100.000000  1.010614e+08
#
#                rain          snow         tempm       thunder       tornado  \
# count  80657.000000  80657.000000  80657.000000  80657.000000  80657.000000
# mean       0.027102      0.000012     26.340045      0.010216      0.000025
# std        0.162383      0.003521      8.242780      0.100558      0.004980
# min        0.000000      0.000000      4.000000      0.000000      0.000000
# 25%        0.000000      0.000000     20.000000      0.000000      0.000000
# 50%        0.000000      0.000000     28.000000      0.000000      0.000000
# 75%        0.000000      0.000000     32.000000      0.000000      0.000000
# max        1.000000      1.000000     72.000000      1.000000      1.000000
#
#                vism         wdire         wspdm
# count  80657.000000  80657.000000  80657.000000
# mean       2.563318    151.841316      8.976131
# std       22.690289    116.152996     12.084670
# min        0.000000      0.000000      0.000000
# 25%        1.800000     45.000000      3.700000
# 50%        2.200000    135.000000      7.400000
# 75%        3.000000    270.000000     13.000000
# max     6436.000000    315.000000   1514.900000

# %% [markdown]
# # Splitting the Data into Training and Testing

# %%
# Creating features
X = df.drop(columns='conds')
# Creating target
y = df['conds']

# %%
X.describe()
# Out:
#              dewptm           fog          hail           hum     pressurem  \
# count  80657.000000  80657.000000  80657.000000  80657.000000  8.065700e+04
# mean      15.676445      0.050907      0.000136     55.171926  2.199730e+03
# std        7.150146      0.219809      0.011677     23.447379  3.558458e+05
# min      -24.000000      0.000000      0.000000      4.000000 -9.999000e+03
# 25%       10.000000      0.000000      0.000000     36.000000  1.001000e+03
# 50%       15.000000      0.000000      0.000000     55.000000  1.008000e+03
# 75%       22.000000      0.000000      0.000000     74.000000  1.014000e+03
# max       35.000000      1.000000      1.000000    100.000000  1.010614e+08
#
#                rain          snow         tempm       thunder       tornado  \
# count  80657.000000  80657.000000  80657.000000  80657.000000  80657.000000
# mean       0.027102      0.000012     26.340045      0.010216      0.000025
# std        0.162383      0.003521      8.242780      0.100558      0.004980
# min        0.000000      0.000000      4.000000      0.000000      0.000000
# 25%        0.000000      0.000000     20.000000      0.000000      0.000000
# 50%        0.000000      0.000000     28.000000      0.000000      0.000000
# 75%        0.000000      0.000000     32.000000      0.000000      0.000000
# max        1.000000      1.000000     72.000000      1.000000      1.000000
#
#                vism         wdire         wspdm
# count  80657.000000  80657.000000  80657.000000
# mean       2.563318    151.841316      8.976131
# std       22.690289    116.152996     12.084670
# min        0.000000      0.000000      0.000000
# 25%        1.800000     45.000000      3.700000
# 50%        2.200000    135.000000      7.400000
# 75%        3.000000    270.000000     13.000000
# max     6436.000000    315.000000   1514.900000

# %%
# Checking the balance of the target values
df['conds'].value_counts()
# Out:
# Haze      65925
# Rain       6022
# Cloudy     5832
# Clear      2878
# Name: conds, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
Counter(y_train)
# Out:
# Counter({'Clear': 2143, 'Haze': 49517, 'Cloudy': 4330, 'Rain': 4502})

# %% [markdown]
# # Naive Random Oversampling

# %%
# Resample the training data with the RandomOversampler
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

Counter(y_resampled)
# Out:
# Counter({'Clear': 49517, 'Haze': 49517, 'Cloudy': 49517, 'Rain': 49517})

# %%
# Train the Logistic Regression model using the resampled data
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

confusion_matrix(y_test, y_pred)
# Out:
# array([[ 258,  214,   13,  250],
#        [ 235,  564,   58,  645],
#        [3624, 6846, 1914, 4024],
#        [  15,  310,   84, 1111]], dtype=int64)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
bal_acc_score=balanced_accuracy_score(y_test, y_pred)
bal_acc_score
# Out:
# 0.3935228023619668

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
ovr_class_rpt=(classification_report_imbalanced(y_test, y_pred))
print(ovr_class_rpt)
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#       Clear       0.06      0.35      0.80      0.11      0.53      0.27       735
#      Cloudy       0.07      0.38      0.61      0.12      0.48      0.22      1502
#        Haze       0.93      0.12      0.96      0.21      0.33      0.10     16408
#        Rain       0.18      0.73      0.74      0.29      0.73      0.54      1520
#
# avg / total       0.77      0.19      0.91      0.20      0.38      0.15     20165
